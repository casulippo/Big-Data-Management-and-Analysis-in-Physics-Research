# %% [markdown]
# # Esame Data Science - a.a. 2021/2022
#
# Di seguitono sono proposti gli esercizi per la prova d'esame.
# Per presentarsi all'esame è necessario aver implementato una soluzione per tutti e 3 gli esercizi.
#
# 1. [Esercizio Classificazioen](#esercizio1)
# 2. [Esercizio Serie Storica](#esercizio2)
# 3. [Predizione di malattie cardiache](#esercizio3)

# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt
sys.path.append('../')

# %% [markdown]
# ! pip install jupyter_contrib_nbextensions

# %% [markdown]
# <a id="esercizio1"></a>
# ## Esercizio Classificazione

# %% [markdown]
# L'Organizzazione mondiale della sanità ha stimato che 12 milioni di decessi si verificano in tutto il mondo, ogni anno a causa di malattie cardiache. La metà dei decessi negli Stati Uniti e in altri paesi sviluppati è dovuta a malattie cardiovascolari. La prognosi precoce delle malattie cardiovascolari può aiutare a prendere decisioni sui cambiamenti dello stile di vita nei pazienti ad alto rischio e, a sua volta, ridurre le complicanze.
#
# In questo esercizio si chiedere di utilizzare i decision tree (e magari i boosted decision trees) per individuare i fattori di rischio / delle malattie cardiache più rilevanti e prevedere il rischio complessivo utilizzando la regressione logistica.

# %% [markdown]
# Il dataset con i dati che useremo si trova nel filw `data/framingham.csv`. Il dataset contiene i seguenti dati:
#
# Demografici:
# - male: maschio o femmina (nominale)
# - age: età del paziente (continua - Sebbene le età registrate siano state troncate a numeri interi, il concetto di età è continuo)
#
# Comportamentali:
# - currentSmoker: se il paziente sia o meno un fumatore attuale (nominale)
# - cigsPerDay: il numero di sigarette che la persona ha fumato in media in un giorno (può essere considerato continuo in quanto si può avere un numero qualsiasi di sigarette, anche mezza sigaretta)
#
# Storia medica:
# - BPMeds: se il paziente assumeva o meno un farmaco per la pressione arteriosa (nominale)
# - prevalentStroke: se il paziente ha avuto o meno un ictus (nominale)
# - prevalentHyp: se il paziente è iperteso (nominale)
# - diabetes: se il paziente ha o meno il diabete (nominale)
#
# Situazione medica attuale:
# - totChol: livello di colesterolo totale (continuo)
# - sysBP: pressione arteriosa sistolica (continua)
# - diaBP: pressione arteriosa diastolica (continua)
# - BMI: indice di massa corporea (continuo)
# - heartRate: frequenza cardiaca (continua - Nella ricerca medica, variabili come la frequenza cardiaca, sebbene in realtà discrete, sono comunque considerate continue a causa del gran numero di possibili valori)
# - glucose: livello di glucosio (continuo)
#
# Variabile che si vuole predire (target desiderato):
# - TenYearCHD: Rischio di malattia coronarica nei prossimi 10 anni CHD (binario: '1' significa sì, '0' significa no)

# %% [markdown]
# Si richiede di leggere il dataset, fare una parte di statistica descrittiva e quindi di provare a creare un albero decisionale sui dati in esso contenuti per descrivere quali variabili influiscono maggiormente sul consumo alcolico nei ragazzi.
#
# L'albero può essere troncato ad una profondità di qualche livello e deve essere allegato e discusso con alcune considerazioni sul dataset.
#
# Dopo la realizzazione dell'albero, viene richiesto di disegnarlo e caricare l'immagine nel notebook (è possibile utilizzare il sito internet visto a lezione (http://webgraphviz.com).
# I risultati ottenuti nell'albero devono essere quindi brevemente commentati.

# %%
framingham = pd.read_csv('../data/framingham.csv')

# %%
framingham
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# 1                   0             0         0    250.0  121.0   81.0  28.73
# 2                   0             0         0    245.0  127.5   80.0  25.34
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...               ...           ...       ...      ...    ...    ...    ...
# 4233                0             1         0    313.0  179.0   92.0  25.97
# 4234                0             0         0    207.0  126.5   80.0  19.71
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
#
#       heartRate  glucose  TenYearCHD
# 0          80.0     77.0           0
# 1          95.0     76.0           0
# 2          75.0     70.0           0
# 3          65.0    103.0           1
# 4          85.0     85.0           0
# ...         ...      ...         ...
# 4233       66.0     86.0           1
# 4234       65.0     68.0           0
# 4235       84.0     86.0           0
# 4236       86.0      NaN           0
# 4237       80.0    107.0           0
#
# [4238 rows x 16 columns]

# %% [markdown]
# ### Statistica descrittiva e studio del dataset

# %% [markdown]
# #### Verifico i type delle colonne

# %%
framingham.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# memory usage: 529.9 KB

# %%
bool_features = ['male', 'currentSmoker', 'BPMeds', 'prevalentStroke', 'prevalentHyp', 'diabetes', 'TenYearCHD']
for e in bool_features:
    framingham[e]=framingham[e].astype('bool')

# %%
framingham.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   bool
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   bool
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4238 non-null   bool
#  6   prevalentStroke  4238 non-null   bool
#  7   prevalentHyp     4238 non-null   bool
#  8   diabetes         4238 non-null   bool
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   bool
# dtypes: bool(7), float64(8), int64(1)
# memory usage: 327.1 KB

# %% [markdown]
# #### Valori nulli

# %%
for column in framingham.columns:
    print(column + ' = ' + str(framingham[column].isna().sum()))
# Out:
# male = 0
# age = 0
# education = 105
# currentSmoker = 0
# cigsPerDay = 29
# BPMeds = 0
# prevalentStroke = 0
# prevalentHyp = 0
# diabetes = 0
# totChol = 50
# sysBP = 0
# diaBP = 0
# BMI = 19
# heartRate = 1
# glucose = 388
# TenYearCHD = 0

# %% [markdown]
# E' necessario prendere una decisione sul trattamento dei valori nulli:
#  - non intervenire e lasciare il dataset così com'è
#  - fillare i valori nulli con la media/mediana o altri valori che influiscano il meno possibile sulla distribuzione
#  - rimuovere l'intera riga

# %% [markdown]
# #### Distribuzione variabili continue

# %%
# Ricavo la lista delle variabili continue
continuous_features = list(set(framingham.columns) - set(bool_features))
continuous_features
# Out:
# ['education',
#  'BMI',
#  'age',
#  'diaBP',
#  'cigsPerDay',
#  'heartRate',
#  'sysBP',
#  'glucose',
#  'totChol']

# %%
for e in continuous_features:
    fig, ax = plt.subplots(figsize = (10,5)) 
    framingham.boxplot(column=e)

# %% [markdown]
# #### Distribuzione variabili booleane

# %%
for e in bool_features:
    fig, ax = plt.subplots(figsize = (10,5))
    plt.title('Conteggio dei valori True e False per la colonna ' + e)
    framingham[e].value_counts().plot(kind='barh', stacked=True)

# %% [markdown]
# ### Correlazione

# %%
framingham.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_3fa63_row0_col0, #T_3fa63_row1_col1, #T_3fa63_row2_col2, #T_3fa63_row3_col3, #T_3fa63_row4_col4, #T_3fa63_row5_col5, #T_3fa63_row6_col6, #T_3fa63_row7_col7, #T_3fa63_row8_col8, #T_3fa63_row9_col9, #T_3fa63_row10_col10, #T_3fa63_row11_col11, #T_3fa63_row12_col12, #T_3fa63_row13_col13, #T_3fa63_row14_col14, #T_3fa63_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3fa63_row0_col1, #T_3fa63_row0_col11, #T_3fa63_row4_col2, #T_3fa63_row6_col3, #T_3fa63_row10_col8, #T_3fa63_row13_col9 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_3fa63_row0_col2, #T_3fa63_row3_col2, #T_3fa63_row6_col5, #T_3fa63_row11_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_3fa63_row0_col3 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_3fa63_row0_col4, #T_3fa63_row7_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_3fa63_row0_col5, #T_3fa63_row0_col9, #T_3fa63_row0_col13, #T_3fa63_row1_col2, #T_3fa63_row1_col3, #T_3fa63_row1_col4, #T_3fa63_row2_col6, #T_3fa63_row2_col10, #T_3fa63_row2_col15, #T_3fa63_row3_col1, #T_3fa63_row3_col6, #T_3fa63_row3_col7, #T_3fa63_row3_col8, #T_3fa63_row3_col10, #T_3fa63_row3_col11, #T_3fa63_row3_col12, #T_3fa63_row3_col14, #T_3fa63_row4_col6, #T_3fa63_row4_col14, #T_3fa63_row13_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3fa63_row0_col6, #T_3fa63_row10_col2 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_3fa63_row0_col7, #T_3fa63_row6_col0, #T_3fa63_row9_col14, #T_3fa63_row14_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_3fa63_row0_col8, #T_3fa63_row2_col13 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_3fa63_row0_col10, #T_3fa63_row12_col4 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_3fa63_row0_col12, #T_3fa63_row5_col12, #T_3fa63_row8_col10, #T_3fa63_row11_col5 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_3fa63_row0_col14, #T_3fa63_row12_col6 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_3fa63_row0_col15, #T_3fa63_row5_col3, #T_3fa63_row5_col9, #T_3fa63_row6_col4, #T_3fa63_row12_col5, #T_3fa63_row15_col5, #T_3fa63_row15_col8 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_3fa63_row1_col0, #T_3fa63_row9_col8 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_3fa63_row1_col5 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_3fa63_row1_col6, #T_3fa63_row5_col8, #T_3fa63_row6_col13, #T_3fa63_row10_col4, #T_3fa63_row10_col6, #T_3fa63_row11_col2, #T_3fa63_row11_col3, #T_3fa63_row13_col8 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_3fa63_row1_col7 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_3fa63_row1_col8, #T_3fa63_row5_col6, #T_3fa63_row6_col11, #T_3fa63_row7_col14, #T_3fa63_row8_col3, #T_3fa63_row9_col3, #T_3fa63_row9_col4, #T_3fa63_row12_col14 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_3fa63_row1_col9 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_3fa63_row1_col10 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_3fa63_row1_col11, #T_3fa63_row3_col0, #T_3fa63_row5_col1 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_3fa63_row1_col12, #T_3fa63_row8_col1, #T_3fa63_row10_col9, #T_3fa63_row13_col11 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_3fa63_row1_col13, #T_3fa63_row7_col3, #T_3fa63_row11_col8, #T_3fa63_row15_col6 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_3fa63_row1_col14, #T_3fa63_row2_col4, #T_3fa63_row4_col13, #T_3fa63_row14_col15 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_3fa63_row1_col15 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_3fa63_row2_col0, #T_3fa63_row8_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_3fa63_row2_col1, #T_3fa63_row2_col11, #T_3fa63_row4_col9, #T_3fa63_row8_col6, #T_3fa63_row9_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_3fa63_row2_col3, #T_3fa63_row10_col14, #T_3fa63_row11_col15, #T_3fa63_row14_col13 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_3fa63_row2_col5, #T_3fa63_row2_col9, #T_3fa63_row4_col11 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_3fa63_row2_col7, #T_3fa63_row4_col1, #T_3fa63_row4_col5, #T_3fa63_row13_col6 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_3fa63_row2_col8, #T_3fa63_row4_col8 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_3fa63_row2_col12, #T_3fa63_row12_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_3fa63_row2_col14, #T_3fa63_row3_col9 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_3fa63_row3_col4, #T_3fa63_row10_col11 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_3fa63_row3_col5 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_3fa63_row3_col13, #T_3fa63_row6_col7 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_3fa63_row3_col15, #T_3fa63_row10_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_3fa63_row4_col0 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_3fa63_row4_col3, #T_3fa63_row11_col10 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_3fa63_row4_col7, #T_3fa63_row9_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_3fa63_row4_col10, #T_3fa63_row12_col3 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_3fa63_row4_col12, #T_3fa63_row6_col9 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_3fa63_row4_col15, #T_3fa63_row7_col0, #T_3fa63_row7_col4, #T_3fa63_row7_col6, #T_3fa63_row8_col2, #T_3fa63_row14_col9 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_3fa63_row5_col0, #T_3fa63_row6_col8 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_3fa63_row5_col2, #T_3fa63_row5_col4, #T_3fa63_row9_col5, #T_3fa63_row12_col8 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_3fa63_row5_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_3fa63_row5_col10 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_3fa63_row5_col11, #T_3fa63_row9_col7, #T_3fa63_row9_col12 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_3fa63_row5_col13, #T_3fa63_row7_col8, #T_3fa63_row11_col4, #T_3fa63_row11_col14 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_3fa63_row5_col14, #T_3fa63_row13_col2, #T_3fa63_row15_col2 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_3fa63_row5_col15, #T_3fa63_row8_col4, #T_3fa63_row9_col15, #T_3fa63_row14_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_3fa63_row6_col1, #T_3fa63_row13_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_3fa63_row6_col2, #T_3fa63_row6_col15, #T_3fa63_row14_col0, #T_3fa63_row14_col2, #T_3fa63_row14_col4 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_3fa63_row6_col10, #T_3fa63_row6_col12, #T_3fa63_row8_col7, #T_3fa63_row12_col13, #T_3fa63_row13_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_3fa63_row6_col14, #T_3fa63_row7_col2, #T_3fa63_row10_col0, #T_3fa63_row13_col5, #T_3fa63_row13_col15 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_3fa63_row7_col5, #T_3fa63_row13_col10, #T_3fa63_row14_col1 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_3fa63_row7_col9, #T_3fa63_row7_col15, #T_3fa63_row11_col9 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_3fa63_row7_col10 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_3fa63_row7_col11 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_3fa63_row7_col12 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_3fa63_row7_col13 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_3fa63_row8_col5, #T_3fa63_row8_col9 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_3fa63_row8_col11, #T_3fa63_row8_col15, #T_3fa63_row15_col9 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_3fa63_row8_col12, #T_3fa63_row14_col12 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_3fa63_row8_col13, #T_3fa63_row13_col14 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_3fa63_row8_col14 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_3fa63_row9_col1 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_3fa63_row9_col2, #T_3fa63_row12_col15, #T_3fa63_row15_col13 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_3fa63_row9_col10 {
#   background-color: #9ebeff;
#   co

# %%
framingham.iloc[:,:-1]
# Out:
#        male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0      True   39        4.0          False         0.0   False
# 1     False   46        2.0          False         0.0   False
# 2      True   48        1.0           True        20.0   False
# 3     False   61        3.0           True        30.0   False
# 4     False   46        3.0           True        23.0   False
# ...     ...  ...        ...            ...         ...     ...
# 4233   True   50        1.0           True         1.0   False
# 4234   True   51        3.0           True        43.0   False
# 4235  False   48        2.0           True        20.0    True
# 4236  False   44        1.0           True        15.0   False
# 4237  False   52        2.0          False         0.0   False
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0               False         False     False    195.0  106.0   70.0  26.97
# 1               False         False     False    250.0  121.0   81.0  28.73
# 2               False         False     False    245.0  127.5   80.0  25.34
# 3               False          True     False    225.0  150.0   95.0  28.58
# 4               False         False     False    285.0  130.0   84.0  23.10
# ...               ...           ...       ...      ...    ...    ...    ...
# 4233            False          True     False    313.0  179.0   92.0  25.97
# 4234            False         False     False    207.0  126.5   80.0  19.71
# 4235            False         False     False    248.0  131.0   72.0  22.00
# 4236            False         False     False    210.0  126.5   87.0  19.16
# 4237            False         False     False    269.0  133.5   83.0  21.47
#
#       heartRate  glucose
# 0          80.0     77.0
# 1          95.0     76.0
# 2          75.0     70.0
# 3          65.0    103.0
# 4          85.0     85.0
# ...         ...      ...
# 4233       66.0     86.0
# 4234       65.0     68.0
# 4235       84.0     86.0
# 4236       86.0      NaN
# 4237       80.0    107.0
#
# [4238 rows x 15 columns]

# %%
from sklearn.model_selection import train_test_split

#framingham['TenYearCHD'] = framingham.Survived.astype('bool')

X = framingham.iloc[:,:-1]
X = pd.get_dummies(X, columns=X.columns)
y = framingham.TenYearCHD

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(max_depth=3)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
d = framingham
d['prediction'] = clf.predict(X)
d['real_data'] = y
d[['prediction', 'real_data']]
# Out:
#       prediction  real_data
# 0          False      False
# 1          False      False
# 2          False      False
# 3          False       True
# 4          False      False
# ...          ...        ...
# 4233       False       True
# 4234       False      False
# 4235       False      False
# 4236       False      False
# 4237       False      False
#
# [4238 rows x 2 columns]

# %%
len(d[d['prediction'] != d['real_data']]), len(d[d['prediction'] == d['real_data']])
# Out:
# (631, 3607)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(25,10))
_ = tree.plot_tree(clf, 
                   feature_names=X.columns,
                   filled=True)

# %% [markdown]
# <a id="esercizio2"></a>
# ## Esercizio serie storica

# %% [markdown]
# Questo secondo esercizio richiede di effettuare un'analisi di dati di serie storica.
#
# Leggendo il dataset `data/globaltemperatures.csv`, caricare i dati della media della temperatura nei diversi mesi dell'anno dal 1750. Plottare la serie dati, analizarne le caratteristiche (tendenza e stagionalità) e provare a fare una regressione lineare del trend (per valutarne la tendenza). Per fare regressione lineare di una timeseries è conveniente trasformare l'indice (l'asse X) in un numero che indica il numero di periodi passati dal momento inziale.
#
# Infine provare a usare la serie storica per produrre le temperature dei successivi 10 anni.

# %% [markdown]
# <a id="esercizio3"></a>
# ## Predizione di malattie cardiache

# %% [markdown]
# Prevedere se un paziente ha probabilità una malattia cardiaca o meno. Abbiamo un dato che classifica se i pazienti hanno o meno malattie cardiache in base alle caratteristiche in esso contenute. Cercheremo di utilizzare questi dati per creare un modello che tenti di prevedere se un paziente ha questa malattia o meno.
#
# Il set di dati è memorizzato nel file `heart.csv` e preso da
# https://archive.ics.uci.edu/ml/datasets/Heart+Malattia
